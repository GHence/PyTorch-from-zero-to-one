# %% [markdown]
# ### 多项式回归模型
#
# 下面我们更进一步，讲一讲多项式回归。什么是多项式回归呢？非常简单，根据上面的线性回归模型
#
# $$
# \hat{y} = w x + b
# $$
#
# 这里是关于 x 的一个一次多项式，这个模型比较简单，没有办法拟合比较复杂的模型，所以我们可以使用更高次的模型，比如
#
# $$
# \hat{y} = w_0 + w_1 x + w_2 x^2 + w_3 x^3 + \cdots
# $$
#
# 这样就能够拟合更加复杂的模型，这就是多项式模型，这里使用了 x 的更高次，同理还有多元回归模型，形式也是一样的，只是出了使用 x，还是更多的变量，比如 y、z 等等，同时他们的 loss 函数和简单的线性回归模型是一致的。

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.autograd import Variable

# %%
import time    # 计时函数

POLY_DEGREE = 3   # 例子中的x最高次幂为3

# %%
W_target = torch.FloatTensor([10, 20, 30]).reshape(3, 1)
b_target = torch.FloatTensor([5])
 
start = time.time()
 
 
def f(x):
    return x.mm(W_target)+b_target[0]  # x--(32, 3)   W---(3, 1)   b---(1)
 
 
# cat()    eg:  A---(2, 3)    B----(4, 3)  C----(2, 4)  则 torch.cat((A,B), 0) -----(6, 3)    torch.cat((A,C), 1)------(2, 7)
def make_features(x):
    x = x.reshape(-1, 1)   
#     print("make_feature x_shape = ",x.shape)
    tmp = [x ** i for i in range(1, POLY_DEGREE+1)]
    out = torch.cat(tmp, 1)   # https://www.cnblogs.com/JeasonIsCoding/p/10162356.html  
#     print("make_feature out_shape = ",out.shape)
    return out
 
 
def get_batch(batch_size=32):
    random = torch.randn(batch_size)
#     print("random shape = ", random.shape)
    random = sorted(random)
    random = torch.tensor(random)
    x = make_features(random)
#     print("get_batch x.shape", x.shape)
    y = f(x)
#     print("get_batch y.shape", y.shape)
    # return Variable(x).cuda(), Variable(y).cuda()
    return Variable(x), Variable(y)
 
 
class poly_model(nn.Module):
    """ Define Model """
 
    def __init__(self):
        super().__init__()
        self.poly = nn.Linear(3, 1)
 
    def forward(self, input):
        out = self.poly(input)
        return out
 
 
# if torch.cuda.is_available():
#     model = poly_model().cuda()
# else:
#     model = poly_model()
model = poly_model()

 
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
 
 
py = []
 
 
def plot(print_loss):
    plt.figure(1)
    plt.cla()
    py.append(print_loss)
    plt.plot(py, 'bo-', linewidth=2, markersize=4,
             markeredgecolor='red', markerfacecolor='green')
    plt.pause(0.0000001)

# %%
epoch = 0
while True:
    batch_x, batch_y = get_batch()
    output = model(batch_x)
    loss = criterion(output, batch_y)
    print_loss = loss.data.item()
 
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
 
    epoch += 1
    if(print_loss < 1e-3):
        break
    if(epoch % 100 == 0):
        print('epoch:' + str(epoch) + '  loss =  '+str(print_loss))
        plot(print_loss)
 
end = time.time()
print('time cost is {}'.format(end-start))
 
torch.save(model, 'model/model.pkl')
 
model.eval()
print(model.poly.weight)
print(model.poly.bias)
# Out:
# epoch:100  loss =  227.52139282226562
# epoch:200  loss =  32.026432037353516
# epoch:300  loss =  30.92771339416504
# epoch:400  loss =  26.29631996154785
# epoch:500  loss =  2.746607542037964
# epoch:600  loss =  2.3244478702545166
# epoch:700  loss =  4.975978374481201
# epoch:800  loss =  2.015406847000122
# epoch:900  loss =  1.205359935760498
# epoch:1000  loss =  1.0199323892593384
# epoch:1100  loss =  0.9682430624961853
# epoch:1200  loss =  0.8304374814033508
# epoch:1300  loss =  0.7312902808189392
# epoch:1400  loss =  0.8770503997802734
# epoch:1500  loss =  0.3745619058609009
# epoch:1600  loss =  0.27974796295166016
# epoch:1700  loss =  0.4079694151878357
# epoch:1800  loss =  0.4777584373950958
# epoch:1900  loss =  0.18506072461605072
# epoch:2000  loss =  0.17022699117660522
# epoch:2100  loss =  0.14529655873775482
# epoch:2200  loss =  0.14091232419013977
# epoch:2300  loss =  0.10859023779630661
# epoch:2400  loss =  0.08809788525104523
# ...

# %%
xx, yy = get_batch()
print("xx.shape{}, yy.shape{}".format(xx.shape, yy.shape))
x = xx.data.numpy()
print("x.shape = ", x.shape)
y5 = x[:, 1]
x = x[:, 0]
print('x[:, 0].shape', x.shape)

print('x[:, 1].shape', y5.shape)
# plt.figure(0)
plt.plot(x, yy.data.numpy(), 'ro')
 
 
tx = torch.linspace(-3, 10, 100)
fx = make_features(tx)
fx = Variable(fx)
predict = model(fx)
predict = predict.data.numpy()
plt.plot(tx.numpy(), predict)
 
plt.show()
# Out:
# xx.shapetorch.Size([32, 3]), yy.shapetorch.Size([32, 1])
# x.shape =  (32, 3)
# x[:, 0].shape (32,)
# x[:, 1].shape (32,)
